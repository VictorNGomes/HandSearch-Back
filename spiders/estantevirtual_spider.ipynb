# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
#%matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
no_pages = 2
search = "dan+brown"

def get_data(pageNo, searchTitle):  
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
    #https://www.estantevirtual.com.br/busca?utf8=%E2%9C%93&q=dan%20brown&livro_novo=1&offset=2
    r = requests.get('https://www.estantevirtual.com.br/busca?q='+str(searchTitle)+'&livro_novo=1&offset='+str(pageNo), headers=headers)#, proxies=proxies)
    content = r.content
    soup = BeautifulSoup(content)
    #print(soup)

    alls = []
    for d in soup.findAll('div', attrs={'class':'livro exibe-desagrupado'}):
        #print(d)
        name = d.find('h2', attrs={'itemprop':'name'})
        #n = name.find_all('img', alt=True)
        #print(n[0]['alt'])
        author = d.find('span', attrs={'itemprop':'author'} )
        #rating = d.find('span', attrs={'class':'4,1 de 5 estrelas'})
        #r = rating.find_all('span', aria-label=True)
        
        price = d.find('span', attrs={'class':'preco'})

        all1=[]

        if name is not None:
            #print(n[0]['alt'])
            all1.append(name.text)
        else:
            all1.append("unknown-product")

        if author is not None:
            #print(author.text)
            all1.append(author.text)
        elif author is None:
            author = d.find('span', attrs={'class':'a-size-small a-color-base'})
            if author is not None:
                all1.append(author.text)
            else:    
                all1.append('0')

        #if rating is not None:
            #print(rating.text)
        #    all1.append(rating.text)
        #else:
        #    all1.append('-1')

        #if users_rated is not None:
            #print(price.text)
        #    all1.append(users_rated.text)
        #else:
        #    all1.append('0')     

        if price is not None:
            #print(price.text)
            all1.append(price.text)
        else:
            all1.append('0')
        alls.append(all1)    
    return alls

# %%
results = []
for i in range(1, no_pages+1):
    results.append(get_data(i, search))
flatten = lambda l: [item for sublist in l for item in sublist]
df = pd.DataFrame(flatten(results),columns=['Titulo','Autor', 'Preco'])
df.to_csv('estante_products.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv("amazon_products.csv")
df.shape
# Out:
# (45, 3)

# %%
df.head(61)
# Out:
#                                                Titulo  \
# 0   \n      O Caderno de Viagens de o Codigo da Vi...
# 1                 \n      Desvendando o Inferno\n
# 2                    \n      Ponto de Impacto P\n
# 3                   \n      O Código da Vinci P\n
# 4                   \n      O Código da Vinci P\n
# 5   \n      O Caderno de Viagens de o Codigo da Vi...
# 6   \n      O Caderno de Viagens de o Codigo da Vi...
# 7   \n      O Caderno de Viagens de o Codigo da Vi...
# 8   \n      O Caderno de Viagens de o Codigo da Vi...
# 9   \n      O Caderno de Viagens de o Codigo da Vi...
# 10  \n      DESVENDANDO INFERNO - O GUIA ESSENCIAL...
# 11              \n      Inferno ( Letra Grande)\n
# 12  \n      Homem por trás de o código da vinci, u...
# 13                       \n      The los Symbol\n
# 14             \n      Inferno   - Nao e Pocket\n
# 15  \n      A Filosofia de o Símbolo Perdido - Gui...
# 16  \n      Os Segredos de o Símbolo Perdido /// D...
# 17  \n      Caderno de Viagens do Codigo da Vinci\...
# 18                    \n      O Codigo da Vinci\n
# 19  \n      Inferno: o Maior Desafio de Robert Lan...
# 20     \n      Fortaleza Digital (não é Pocket)\n
# 21    \n      Fortaleza Digital  - Nao e Pocket\n
# 22        \n      SIMBOLO PERDIDO DE DAN BROW,O\n
# 23        \n      SIMBOLO PERDIDO DE DAN BROW,O\n
# 24        \n      SIMBOLO PERDIDO DE DAN BROW,O\n
# 25        \n      SIMBOLO PERDIDO DE DAN BROW,O\n
# 26        \n      SIMBOLO PERDIDO DE DAN BROW,O\n
# 27  \n      Inferno: o Maior Desafio de Robert Lan...
# 28                   \n      Inferno F. Simples\n
# 29             \n      Inferno (Robert Langdon)\n
# 30             \n      Inferno (Robert Langdon)\n
# 31             \n      Inferno (Robert Langdon)\n
# 32             \n      Inferno (Robert Langdon)\n
# 33                     \n      Ponto de Impacto\n
# 34     \n      Anjos e Demônios - Capa do Filme\n
# 35                        \n      Origem (novo)\n
# 36                     \n      ORIGEM DAN BROWN\n
# 37              \n      Sinfonia Dos Animais, A\n
# 38              \n      Sinfonia Dos Animais, A\n
# 39              \n      Sinfonia Dos Animais, A\n
# 40              \n      Sinfonia Dos Animais, A\n
# 41              \n      Sinfonia Dos Animais, A\n
# 42              \n      Sinfonia Dos Animais, A\n
# 43              \n      Sinfonia Dos Animais, A\n
# 44              \n      Sinfonia Dos Animais, A\n
#
#                                               Autor     Preco
# 0       \n      Baseado no Livro de Dan Brown\n       R$ 4,00
# 1                           \n      Dan Brown\n       R$ 9,90
# 2                           \n      Dan Brown\n      R$ 10,00
# 3                           \n      Dan Brown\n      R$ 12,00
# 4                           \n      Dan Brown\n      R$ 13,00
# 5                           \n      Dan Brown\n      R$ 14,00
# 6                           \n      Dan Brown\n      R$ 14,00
# 7                           \n      Dan Brown\n      R$ 14,00
# 8                           \n      Dan Brown\n      R$ 14,00
# 9                           \n      Dan Brown\n      R$ 14,00
# 10                       \n      MICHAEL HAAG\n      R$ 15,00
# 11                          \n      Dan Brown\n      R$ 15,00
# 12                         \n      Lisa Rogak\n      R$ 15,00
# 13                          \n      Dan Brown\n      R$ 16,00
# 14                          \n      Dan Brown\n      R$ 19,35
# 15                    \n      Thomas R. Beyer\n      R$ 20,00
# 16     \n      Dan Burstein e Arne de Keijzer\n      R$ 20,00
# 17                          \n      Dan Brawn\n      R$ 20,00
# 18                      \n      Dan Brown 229\n      R$ 21,90
# 19                          \n      Dan Brown\n      R$ 23,00
# 20                          \n      Dan Brown\n      R$ 24,00
# 21                          \n      Dan Brown\n      R$ 24,19
# 22                      \n      Carmine, Alex\n      R$ 25,14
# 23                      \n      Carmine, Alex\n      R$ 25,14
# 24                      \n      Carmine, Alex\n      R$ 25,14
# 25                      \n      Carmine, Alex\n      R$ 25,14
# 26                      \n      Carmine, Alex\n      R$ 25,14
# 27                          \n      Dan Brown\n      R$ 25,99
# 28                          \n      Dan Brown\n      R$ 29,90
# 29                         \n      Brown, Dan\n      R$ 29,90
# 30                         \n      Brown, Dan\n      R$ 29,90
# 31                         \n      Brown, Dan\n      R$ 29,90
# 32                         \n      Brown, Dan\n      R$ 29,90
# 33                      \n      Dan Brown 690\n      R$ 29,90
# 34  \n      Dan Brown; Maria Luiza Newland...\n      R$ 35,00
# 35                          \n      Dan Brown\n      R$ 35,00
# 36                     \n      VÁRIOS AUTORES\n      R$ 35,06
# 37                          \n      Dan Brown\n      R$ 37,14
# 38                          \n      Dan Brown\n      R$ 37,14
# 39                          \n      Dan Brown\n      R$ 37,14
# 40                          \n      Dan Brown\n      R$ 37,14
# 41                          \n      Dan Brown\n      R$ 37,14
# 42                          \n      Dan Brown\n      R$ 37,14
# 43                          \n      Dan Brown\n      R$ 37,14
# 44                          \n      Dan Brown\n      R$ 37,14
